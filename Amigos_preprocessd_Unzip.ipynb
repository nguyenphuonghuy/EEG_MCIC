# %%
from __future__ import print_function
import os
from scipy.io import loadmat
from scipy import signal
import matplotlib
import scipy.io as sio
import numpy as np
import math
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import uniform
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import simps

# %%
import zipfile
import os

source_folder = "/content/drive/MyDrive/AMIGOS/Data_preprocessd"
destination_folder = "/content/drive/MyDrive/AMIGOS/Data_preprocessd_Unzip"

# Đảm bảo thư mục đích tồn tại
os.makedirs(destination_folder, exist_ok=True)

# Giải nén từng tệp ZIP, bỏ qua tệp P39.zip
for i in range(1, 41):
    if i == 39:
        print("Bỏ qua tệp Data_Preprocessed_P39.zip do bị lỗi")
        continue

    zip_filename = f"Data_Preprocessed_P{i:02d}.zip"
    zip_filepath = os.path.join(source_folder, zip_filename)

    try:
        with zipfile.ZipFile(zip_filepath, 'r') as zip_ref:
            zip_ref.extractall(destination_folder)
        print(f"Giải nén hoàn tất {zip_filename}")
    except zipfile.BadZipFile:
        print(f"Lỗi: Tệp ZIP bị hỏng {zip_filename}")
    except Exception as e:
        print(f"Lỗi khác với tệp {zip_filename}: {e}")

print("Quá trình giải nén hoàn tất!")
# Out:
# Giải nén hoàn tất Data_Preprocessed_P01.zip
# Giải nén hoàn tất Data_Preprocessed_P02.zip
# Giải nén hoàn tất Data_Preprocessed_P03.zip
# Giải nén hoàn tất Data_Preprocessed_P04.zip
# Giải nén hoàn tất Data_Preprocessed_P05.zip
# Giải nén hoàn tất Data_Preprocessed_P06.zip
# Giải nén hoàn tất Data_Preprocessed_P07.zip
# Giải nén hoàn tất Data_Preprocessed_P08.zip
# Giải nén hoàn tất Data_Preprocessed_P09.zip
# Giải nén hoàn tất Data_Preprocessed_P10.zip
# Giải nén hoàn tất Data_Preprocessed_P11.zip
# Giải nén hoàn tất Data_Preprocessed_P12.zip
# Giải nén hoàn tất Data_Preprocessed_P13.zip
# Giải nén hoàn tất Data_Preprocessed_P14.zip
# Giải nén hoàn tất Data_Preprocessed_P15.zip
# Giải nén hoàn tất Data_Preprocessed_P16.zip
# Giải nén hoàn tất Data_Preprocessed_P17.zip
# Giải nén hoàn tất Data_Preprocessed_P18.zip
# Giải nén hoàn tất Data_Preprocessed_P19.zip
# Giải nén hoàn tất Data_Preprocessed_P20.zip
# Giải nén hoàn tất Data_Preprocessed_P21.zip
# Giải nén hoàn tất Data_Preprocessed_P22.zip
# Giải nén hoàn tất Data_Preprocessed_P23.zip
# Giải nén hoàn tất Data_Preprocessed_P24.zip
# Giải nén hoàn tất Data_Preprocessed_P25.zip
# Giải nén hoàn tất Data_Preprocessed_P26.zip
# Giải nén hoàn tất Data_Preprocessed_P27.zip
# Giải nén hoàn tất Data_Preprocessed_P28.zip
# Giải nén hoàn tất Data_Preprocessed_P29.zip
# Giải nén hoàn tất Data_Preprocessed_P30.zip
# Giải nén hoàn tất Data_Preprocessed_P31.zip
# Giải nén hoàn tất Data_Preprocessed_P32.zip
# Giải nén hoàn tất Data_Preprocessed_P33.zip
# Giải nén hoàn tất Data_Preprocessed_P34.zip
# Giải nén hoàn tất Data_Preprocessed_P35.zip
# Giải nén hoàn tất Data_Preprocessed_P36.zip
# Giải nén hoàn tất Data_Preprocessed_P37.zip
# Giải nén hoàn tất Data_Preprocessed_P38.zip
# Bỏ qua tệp Data_Preprocessed_P39.zip do bị lỗi
# Giải nén hoàn tất Data_Preprocessed_P40.zip
# Quá trình giải nén hoàn tất!

# %%
import zipfile
import os

source_folder = "/content/drive/MyDrive/AMIGOS/Data_preprocessd"
destination_folder = "/content/drive/MyDrive/AMIGOS/Data_preprocessd_Unzip"

# Đảm bảo thư mục đích tồn tại
os.makedirs(destination_folder, exist_ok=True)

# Giải nén từng tệp ZIP
for i in range(1, 41):
    zip_filename = f"Data_Preprocessed_P{i:02d}.zip"
    zip_filepath = os.path.join(source_folder, zip_filename)

    try:
        with zipfile.ZipFile(zip_filepath, 'r') as zip_ref:
            zip_ref.extractall(destination_folder)
        print(f"Giải nén hoàn tất {zip_filename}")
    except zipfile.BadZipFile:
        print(f"Lỗi: Tệp ZIP bị hỏng {zip_filename}")
    except Exception as e:
        print(f"Lỗi khác với tệp {zip_filename}: {e}")

print("Quá trình giải nén hoàn tất!")
# Out:
# Giải nén hoàn tất Data_Preprocessed_P01.zip
# Giải nén hoàn tất Data_Preprocessed_P02.zip
# Giải nén hoàn tất Data_Preprocessed_P03.zip
# Giải nén hoàn tất Data_Preprocessed_P04.zip
# Giải nén hoàn tất Data_Preprocessed_P05.zip
# Giải nén hoàn tất Data_Preprocessed_P06.zip
# Giải nén hoàn tất Data_Preprocessed_P07.zip
# Giải nén hoàn tất Data_Preprocessed_P08.zip
# Giải nén hoàn tất Data_Preprocessed_P09.zip
# Giải nén hoàn tất Data_Preprocessed_P10.zip
# Giải nén hoàn tất Data_Preprocessed_P11.zip
# Giải nén hoàn tất Data_Preprocessed_P12.zip
# Giải nén hoàn tất Data_Preprocessed_P13.zip
# Giải nén hoàn tất Data_Preprocessed_P14.zip
# Giải nén hoàn tất Data_Preprocessed_P15.zip
# Giải nén hoàn tất Data_Preprocessed_P16.zip
# Giải nén hoàn tất Data_Preprocessed_P17.zip
# Giải nén hoàn tất Data_Preprocessed_P18.zip
# Giải nén hoàn tất Data_Preprocessed_P19.zip
# Giải nén hoàn tất Data_Preprocessed_P20.zip
# Giải nén hoàn tất Data_Preprocessed_P21.zip
# Giải nén hoàn tất Data_Preprocessed_P22.zip
# Giải nén hoàn tất Data_Preprocessed_P23.zip
# Giải nén hoàn tất Data_Preprocessed_P24.zip
# Giải nén hoàn tất Data_Preprocessed_P25.zip
# Giải nén hoàn tất Data_Preprocessed_P26.zip
# Giải nén hoàn tất Data_Preprocessed_P27.zip
# Giải nén hoàn tất Data_Preprocessed_P28.zip
# Giải nén hoàn tất Data_Preprocessed_P29.zip
# Giải nén hoàn tất Data_Preprocessed_P30.zip
# Giải nén hoàn tất Data_Preprocessed_P31.zip
# Giải nén hoàn tất Data_Preprocessed_P32.zip
# Giải nén hoàn tất Data_Preprocessed_P33.zip
# Giải nén hoàn tất Data_Preprocessed_P34.zip
# Giải nén hoàn tất Data_Preprocessed_P35.zip
# Giải nén hoàn tất Data_Preprocessed_P36.zip
# Giải nén hoàn tất Data_Preprocessed_P37.zip
# Giải nén hoàn tất Data_Preprocessed_P38.zip
# Lỗi khác với tệp Data_Preprocessed_P39.zip: Error -3 while decompressing data: invalid code lengths set
# Giải nén hoàn tất Data_Preprocessed_P40.zip
# Quá trình giải nén hoàn tất!

# %%
fs = 128
#path_amigos = './PARSE/DATA/AMIGOS/Data_Preprocessed_P{}/Data_Preprocessed_P{}.mat'
path_amigos_base = "/content/drive/MyDrive/AMIGOS/Data_preprocessd_Unzip/Data_Preprocessed_P{}/Data_Preprocessed_P{}.mat"

# %%
def preprocessing_normal(data, feature):
    freqs, psd = signal.periodogram(data, fs, scaling='density')
    # Define delta lower and upper limits
    low, high = 3, 7
    idx_min = np.argmax(freqs > low) - 1
    idx_max = np.argmax(freqs > high) - 1
    idx_delta = np.zeros(dtype=bool, shape=freqs.shape)
    idx_delta[idx_min:idx_max] = True


    delta_power = simps(psd[idx_delta], freqs[idx_delta])
    total_power = simps(psd, freqs)
    delta_rel_power = delta_power / (total_power)  # to avoid bad channels zeroing total_power
    # Define theta lower and upper limits
    low, high = 8, 10
    idx_min = np.argmax(freqs > low) - 1
    idx_max = np.argmax(freqs > high) - 1
    idx_theta = np.zeros(dtype=bool, shape=freqs.shape)
    idx_theta[idx_min:idx_max] = True
    #print('idx_max', idx_max)
    theta_power = simps(psd[idx_theta], freqs[idx_theta])
    theta_rel_power = theta_power / (total_power)
    # Define alpha lower and upper limits
    low, high = 8, 13
    idx_min = np.argmax(freqs > low) - 1
    idx_max = np.argmax(freqs > high) - 1
    idx_alpha = np.zeros(dtype=bool, shape=freqs.shape)
    idx_alpha[idx_min:idx_max] = True
    alpha_power = simps(psd[idx_alpha], freqs[idx_alpha])
    alpha_rel_power = alpha_power / (total_power)
    # Define beta lower and upper limits
    low, high = 14, 29
    idx_min = np.argmax(freqs > low) - 1
    idx_max = np.argmax(freqs > high) - 1
    idx_beta = np.zeros(dtype=bool, shape=freqs.shape)
    idx_beta[idx_min:idx_max] = True
    beta_power = simps(psd[idx_beta], freqs[idx_beta])
    beta_rel_power = beta_power / (total_power)

    low, high = 30, 45
    idx_min = np.argmax(freqs > low) - 1
    idx_max = np.argmax(freqs > high) - 1
    idx_gamma = np.zeros(dtype=bool, shape=freqs.shape)
    idx_gamma[idx_min:idx_max] = True
    gamma_power = simps(psd[idx_gamma], freqs[idx_gamma])
    gamma_rel_power = gamma_power / (total_power)

    feature = [delta_rel_power, theta_rel_power, alpha_rel_power, beta_rel_power, gamma_rel_power]

    return feature


'''AMIGOS specific: theta (3-7 Hz), slow alpha (8-10 Hz), alpha (8-13 Hz), beta(14-29 Hz) and gamma (30-47 Hz)'''
# Out:
# 'AMIGOS specific: theta (3-7 Hz), slow alpha (8-10 Hz), alpha (8-13 Hz), beta(14-29 Hz) and gamma (30-47 Hz)'

# %%
def preprocessing_amigos(raw, feature):
    overall    = signal.firwin(9,[0.046875, 0.734375],   window='hamming')
    theta      = signal.firwin(9,[0.046875, 0.109375],   window='hamming')
    slow_alpha = signal.firwin(9,[0.125,    0.15625],    window='hamming')
    alpha      = signal.firwin(9,[0.125,    0.203125],   window='hamming')
    beta       = signal.firwin(9,[0.21875,  0.453125],   window='hamming')
    gamma      = signal.firwin(9,[0.46875,  0.734375],   window='hamming')

    # overall    = signal.firwin(9,[3, 47],   window='hamming', fs=128)
    # theta      = signal.firwin(9,[3, 7],   window='hamming', fs=128)
    # slow_alpha = signal.firwin(9,[8, 10],    window='hamming', fs=128)
    # alpha      = signal.firwin(9,[8, 13],   window='hamming', fs=128)
    # beta       = signal.firwin(9,[14,29],   window='hamming', fs=128)
    # gamma      = signal.firwin(9,[30,47],   window='hamming', fs=128)


    filted_Data        = signal.filtfilt(overall,   1, raw)
    filted_theta       = signal.filtfilt(theta,     1, filted_Data)
    filted_slow_alpha  = signal.filtfilt(slow_alpha,1, filted_Data)
    filted_alpha       = signal.filtfilt(alpha,     1, filted_Data)
    filted_beta        = signal.filtfilt(beta,      1, filted_Data)
    filted_gamma       = signal.filtfilt(gamma,     1, filted_Data)


    _,psd_theta        = signal.welch(filted_theta,      fs=128, nperseg=128)
    _,psd_slow_alpha   = signal.welch(filted_slow_alpha, fs=128, nperseg=128)
    _,psd_alpha        = signal.welch(filted_alpha,      fs=128, nperseg=128)
    _,psd_beta         = signal.welch(filted_beta,       fs=128, nperseg=128)
    _,psd_gamma        = signal.welch(filted_gamma,      fs=128, nperseg=128)

    # offset = 0.001
    # if math.isnan(simps(psd_theta)) or math.isnan(simps(psd_gamma)) or math.isnan(simps(psd_alpha)) or math.isnan(simps(psd_beta)):
    #     exit(0)

    feature.append(simps(psd_theta))
    feature.append(simps(psd_slow_alpha))
    feature.append(simps(psd_alpha))
    feature.append(simps(psd_beta))
    feature.append(simps(psd_gamma))

    # feature.append(psd_theta.mean())
    # feature.append(psd_slow_alpha.mean())
    # feature.append(psd_alpha.mean())
    # feature.append(psd_beta.mean())
    # feature.append(psd_gamma.mean())

    return np.log10(feature)

# %%
def EEG_segment(signal):  #14 EEG channels

    first_segment = signal[:20*fs,:]
    last_segment = signal[-20*fs:,:]

    '''start from 5s of signal, 20s per segment'''

    segments_len = math.floor((len(signal)-5*fs)/(20*fs))

    segments = np.zeros((segments_len, 20*fs, 14))

    for i in range(segments_len):
        segments[i] = signal[(i+5)*fs:(i+5+20)*fs, :]

    first_segment  = np.expand_dims(first_segment, axis=0)
    last_segment   = np.expand_dims(last_segment, axis=0)

    total_segments = np.vstack((first_segment, segments, last_segment))

    return total_segments

# %%
def labeling_EEG(participant):#(file_name_csv,raw):

    raw = loadmat(path_amigos_base.format(participant, participant))

    # labels = np.zeros((18, 2))

    '''labeling'''

    valence_list, arousal_list = [], []
    threshold = 0.0

    for video in range(20):

        valence = raw['labels_ext_annotation'][0,video][:,1].astype(float)>(threshold)
        arousal = raw['labels_ext_annotation'][0,video][:,2].astype(float)>(threshold)

        valence_list =valence_list + valence.tolist()
        arousal_list =arousal_list + arousal.tolist()


    valence_arr =np.expand_dims(np.array(valence_list).astype(int), 1)
    arousal_arr =np.expand_dims(np.array(arousal_list).astype(int), 1)


    labels_arr = np.hstack((valence_arr, arousal_arr))


    '''data_processing'''

    EEG_segments_temp = np.zeros((0, 20*fs, 14))
    for video in range(20):
        EEG = raw['joined_data'][0,video][:,0:14]
        EEG_segments = EEG_segment(EEG)
        EEG_segments_temp = np.vstack((EEG_segments_temp, EEG_segments))


    '''feature_extraction'''

    EEG_segment_total = np.transpose(EEG_segments_temp, (0, 2, 1))

    total_features_arr = np.zeros((len(EEG_segment_total), 105))

    for segment_num in range(len(EEG_segment_total)):

        features_list = np.zeros((14, 5))
        for channel_num in range(14):
            signal  = EEG_segment_total[segment_num, channel_num]
            feature = []
            features_list[channel_num] = preprocessing_amigos(signal, feature)
            # if any(math.isnan(i) for i in features_list[channel_num]):
            #     print(segment_num, signal)
            #
            #     exit(0)
            # plt.plot((features_list[channel_num]))
            # plt.show()

            asymmetric_features = np.zeros((7, 5))
            for asy_channel_num in range(7):

                asymmetric_features[asy_channel_num] = features_list[asy_channel_num] - features_list[-(asy_channel_num+1)]

        total_features_arr[segment_num] = features_list.flatten().tolist() + asymmetric_features.flatten().tolist()


    return total_features_arr, labels_arr

# %%
import os
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat

# Thư mục chứa các tệp .mat sau khi đã được giải nén
data_folder = "/content/drive/MyDrive/AMIGOS/Data_preprocessd_Unzip/"
# Thư mục chứa các tệp được lưu trữ sau xử lý
destination_folder = "/content/drive/MyDrive/AMIGOS/Data_preprocessd_Unzip/EEG"
exclude_list = [8, 24, 28]

# Đảm bảo thư mục đích tồn tại
os.makedirs(os.path.join(destination_folder, 'EEG/psd'), exist_ok=True)
os.makedirs(os.path.join(destination_folder, 'EEG/label'), exist_ok=True)

def labeling_EEG(participant):
    mat_file_path = os.path.join(data_folder, f'Data_Preprocessed_P{participant:02d}', f'Data_Preprocessed_P{participant:02d}.mat')
    raw = loadmat(mat_file_path)

    valence_list, arousal_list = [], []
    threshold = 0.0

    for video in range(20):
        valence = raw['labels_ext_annotation'][0, video][:, 1].astype(float) > threshold
        arousal = raw['labels_ext_annotation'][0, video][:, 2].astype(float) > threshold

        valence_list += valence.tolist()
        arousal_list += arousal.tolist()

    valence_arr = np.expand_dims(np.array(valence_list).astype(int), 1)
    arousal_arr = np.expand_dims(np.array(arousal_list).astype(int), 1)

    labels_arr = np.hstack((valence_arr, arousal_arr))

    EEG_segments_temp = np.zeros((0, 20 * fs, 14))
    for video in range(20):
        EEG = raw['joined_data'][0, video][:, 0:14]
        EEG_segments = EEG_segment(EEG)
        EEG_segments_temp = np.vstack((EEG_segments_temp, EEG_segments))

    EEG_segment_total = np.transpose(EEG_segments_temp, (0, 2, 1))
    total_features_arr = np.zeros((len(EEG_segment_total), 105))

    for segment_num in range(len(EEG_segment_total)):
        features_list = np.zeros((14, 5))
        for channel_num in range(14):
            signal = EEG_segment_total[segment_num, channel_num]
            feature = []
            features_list[channel_num] = preprocessing_amigos(signal, feature)

        asymmetric_features = np.zeros((7, 5))
        for asy_channel_num in range(7):
            asymmetric_features[asy_channel_num] = features_list[asy_channel_num] - features_list[-(asy_channel_num + 1)]

        total_features_arr[segment_num] = features_list.flatten().tolist() + asymmetric_features.flatten().tolist()

    return total_features_arr, labels_arr

for participant in tqdm(range(1, 41)):
    if participant not in exclude_list:
        print(f"Processing participant {participant:02d}")
        features, labels = labeling_EEG(participant)
        np.save(os.path.join(destination_folder, 'EEG/psd', f'{participant:02d}.npy'), features)
        np.save(os.path.join(destination_folder, 'EEG/label', f'{participant:02d}.npy'), labels)

print("Lưu dữ liệu hoàn tất!")
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# Processing participant 01
#   2%|▎         | 1/40 [00:20<13:13, 20.35s/it]
# Processing participant 02
#   5%|▌         | 2/40 [00:41<13:05, 20.66s/it]
# Processing participant 03
#   8%|▊         | 3/40 [01:02<12:49, 20.79s/it]
# Processing participant 04
#  10%|█         | 4/40 [01:23<12:29, 20.81s/it]
# Processing participant 05
#  12%|█▎        | 5/40 [01:43<12:05, 20.72s/it]
# Processing participant 06
#  15%|█▌        | 6/40 [02:04<11:41, 20.62s/it]
# Processing participant 07
#  18%|█▊        | 7/40 [02:24<11:17, 20.52s/it]
# Processing participant 09
#  22%|██▎       | 9/40 [02:44<08:03, 15.59s/it]
# Processing participant 10
#  25%|██▌       | 10/40 [03:05<08:29, 16.97s/it]
# Processing participant 11
#  28%|██▊       | 11/40 [03:26<08:39, 17.91s/it]
# Processing participant 12
#  30%|███       | 12/40 [03:46<08:40, 18.59s/it]
# Processing participant 13
#  32%|███▎      | 13/40 [04:07<08:35, 19.10s/it]
# Processing participant 14
#  35%|███▌      | 14/40 [04:28<08:30, 19.62s/it]
# Processing participant 15
#  38%|███▊      | 15/40 [04:48<08:19, 19.97s/it]
# Processing participant 16
#  40%|████      | 16/40 [05:09<08:02, 20.10s/it]
# Processing participant 17
#  42%|████▎     | 17/40 [05:29<07:43, 20.16s/it]
# Processing participant 18
#  45%|████▌     | 18/40 [05:49<07:24, 20.22s/it]
# Processing participant 19
#  48%|████▊     | 19/40 [06:10<07:06, 20.31s/it]
# Processing participant 20
#  50%|█████     | 20/40 [06:31<06:48, 20.45s/it]
# Processing participant 21
#  52%|█████▎    | 21/40 [06:51<06:29, 20.49s/it]
# Processing participant 22
#  55%|█████▌    | 22/40 [07:12<06:09, 20.51s/it]
# Processing participant 23
#  57%|█████▊    | 23/40 [07:33<05:50, 20.59s/it]
# Processing participant 25
#  62%|██████▎   | 25/40 [07:53<03:56, 15.79s/it]
# Processing participant 26
#  65%|██████▌   | 26/40 [08:14<03:57, 16.96s/it]
# Processing participant 27
#  68%|██████▊   | 27/40 [08:34<03:52, 17.89s/it]
# Processing participant 29
#  72%|███████▎  | 29/40 [08:55<02:41, 14.64s/it]
# Processing participant 30
#  75%|███████▌  | 30/40 [09:15<02:39, 15.98s/it]
# Processing participant 31
#  78%|███████▊  | 31/40 [09:35<02:33, 17.07s/it]
# Processing participant 32
#  80%|████████  | 32/40 [09:56<02:24, 18.02s/it]
# Processing participant 33
#  82%|████████▎ | 33/40 [10:17<02:10, 18.70s/it]
# Processing participant 34
#  85%|████████▌ | 34/40 [10:37<01:55, 19.27s/it]
# Processing participant 35
#  88%|████████▊ | 35/40 [10:58<01:38, 19.62s/it]
# Processing participant 36
#  90%|█████████ | 36/40 [11:18<01:19, 19.81s/it]
# Processing participant 37
#  92%|█████████▎| 37/40 [11:38<00:59, 19.99s/it]
# Processing participant 38
#  95%|█████████▌| 38/40 [11:59<00:40, 20.16s/it]
# Processing participant 39
#  98%|█████████▊| 39/40 [12:19<00:18, 18.97s/it]
# Processing participant 40
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/scipy/io/matlab/_mio.py in _open_file(file_like, appendmat, mode)
#      38     try:
# ---> 39         return open(file_like, mode), True
#      40     except OSError as e:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/AMIGOS/Data_preprocessd_Unzip/Data_Preprocessed_P40/Data_Preprocessed_P40.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-acae91a81172> in <cell line: 59>()
#      60     if participant not in exclude_list:
#      61         print(f"Processing participant {participant:02d}")
# ---> 62         features, labels = labeling_EEG(participant)
#      63         np.save(os.path.join(destination_folder, 'EEG/psd', f'{participant:02d}.npy'), features)
#      64         np.save(os.path.join(destination_folder, 'EEG/label', f'{participant:02d}.npy'), labels)
#
# <ipython-input-27-acae91a81172> in labeling_EEG(participant)
#      16 def labeling_EEG(participant):
#      17     mat_file_path = os.path.join(data_folder, f'Data_Preprocessed_P{participant:02d}', f'Data_Preprocessed_P{participant:02d}.mat')
# ---> 18     raw = loadmat(mat_file_path)
#      19
#      20     valence_list, arousal_list = [], []
#
# /usr/local/lib/python3.10/dist-packages/scipy/io/matlab/_mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     223     """
#     224     variable_names = kwargs.pop('variable_names', None)
# --> 225     with _open_file_context(file_name, appendmat) as f:
#     226         MR, _ = mat_reader_factory(f, **kwargs)
#     227         matfile_dict = MR.get_variables(variable_names)
#
# /usr/lib/python3.10/contextlib.py in __enter__(self)
#     133         del self.args, self.kwds, self.func
#     134         try:
# --> 135             return next(self.gen)
#     136         except StopIteration:
#     137             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.10/dist-packages/scipy/io/matlab/_mio.py in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# /usr/local/lib/python3.10/dist-packages/scipy/io/matlab/_mio.py in _open_file(file_like, appendmat, mode)
#      43             if appendmat and not file_like.endswith('.mat'):
#      44                 file_like += '.mat'
# ---> 45             return open(file_like, mode), True
#      46         else:
#      47             raise OSError(
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/AMIGOS/Data_preprocessd_Unzip/Data_Preprocessed_P40/Data_Preprocessed_P40.mat'
